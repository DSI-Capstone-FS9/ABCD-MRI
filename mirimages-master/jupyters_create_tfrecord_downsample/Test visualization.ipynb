# %%
import glob
from nilearn import plotting
import matplotlib.pyplot as plt
import nilearn
import numpy as np
import nibabel as nib
from nilearn.image import crop_img
import os
import tqdm

# %matplotlib inline

# %%
t1 = glob.glob('./data_T1_lowerres/*.gz')
t2 = glob.glob('./data_T2_lowerres/*.gz') 
defusion = glob.glob('./data_defusion_lowerres/*.gz')

# %%
import random
a = [defusion]
random.shuffle(a)
file = a[0][0]
random.shuffle(a)
i = 0

# %%
i = 16

# %%
file = a[0][i]
print(str(i))
print(file)
org = nib.load(file)
print(org.shape)
plotting.plot_anat(org)
plotting.show()
i += 1
# Out:
# 19
# ./data_defusion_lowerres/sub-NDARINVHJDFAMYD_DTI_tensor_mr_DTI_FA.nii.gz
# (64, 64, 64)

# %%
file = './data_DTI_tensor/sub-NDARINV7YCFCH49_DTI_tensor_mr_DTI_RD.nii.gz'
org = nib.load(file)
print(org.shape)
plotting.plot_anat(org)
plotting.show()
# Out:
# (190, 190, 190)
