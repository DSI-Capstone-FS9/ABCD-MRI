# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
import nibabel as nib
import os
import time

import pandas as pd
import numpy as np
import cv2
from skimage.transform import resize

from mricode.utils import log_textfile, createPath, data_generator
from mricode.utils import copy_colab
from mricode.utils import return_iter
from mricode.utils import return_csv
from mricode.config import config

from mricode.models.SimpleCNN_normal_hierach import MyDNN

import tensorflow as tf
from tensorflow.keras.layers import Conv3D
from tensorflow import nn
from tensorflow.python.ops import nn_ops
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.base_layer import InputSpec
from tensorflow.python.keras.utils import conv_utils

tf.__version__
# Out:
# WARNING:tensorflow:Entity <function return_iter.<locals>._parse_ at 0x7f3484eaa598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING: Entity <function return_iter.<locals>._parse_ at 0x7f3484eaa598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING:tensorflow:Entity <function return_iter.<locals>._parse_ at 0x7f33c00618c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING: Entity <function return_iter.<locals>._parse_ at 0x7f33c00618c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING:tensorflow:Entity <function return_iter.<locals>._parse_ at 0x7f3389972ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING: Entity <function return_iter.<locals>._parse_ at 0x7f3389972ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING:tensorflow:Entity <function return_iter.<locals>._parse_ at 0x7f33898b39d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING: Entity <function return_iter.<locals>._parse_ at 0x7f33898b39d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING:tensorflow:Entity <function return_iter.<locals>._parse_ at 0x7f335833c268> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# WARNING: Entity <function return_iter.<locals>._parse_ at 0x7f335833c268> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause:
# '2.0.0'

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
path_output = './output/'
path_tfrecords = '/data2/res64/down/'
path_csv = '/data2/csv/'
filename_res = {'train': 'intell_residual_train.csv', 'val': 'intell_residual_valid.csv', 'test': 'intell_residual_test.csv'}
filename_final = filename_res
sample_size = 'site16_allimages'
batch_size = 8
onlyt1 = False
Model = MyDNN
versionkey = 'down64' #down256, cropped128, cropped64, down64
modelname = 'new_hiearch_allimages_' + versionkey

# %%
createPath(path_output + modelname)

# %%
train_df, val_df, test_df, norm_dict = return_csv(path_csv, filename_final, False)

# %%
train_iter = config[versionkey]['iter_train']
val_iter = config[versionkey]['iter_val']
test_iter = config[versionkey]['iter_test']
t1_mean = config[versionkey]['norm']['t1'][0]
t1_std= config[versionkey]['norm']['t1'][1]
t2_mean=config[versionkey]['norm']['t2'][0]
t2_std=config[versionkey]['norm']['t2'][1]
ad_mean=config[versionkey]['norm']['ad'][0]
ad_std=config[versionkey]['norm']['ad'][1]
fa_mean=config[versionkey]['norm']['fa'][0]
fa_std=config[versionkey]['norm']['fa'][1]
md_mean=config[versionkey]['norm']['md'][0]
md_std=config[versionkey]['norm']['md'][1]
rd_mean=config[versionkey]['norm']['rd'][0]
rd_std=config[versionkey]['norm']['rd'][1]

# %%
norm_dict
# Out:
# {'BMI': {'mean': 18.681548127052135, 'std': 4.193043131845343},
#  'age': {'mean': 119.00325844623563, 'std': 7.479129774017182},
#  'height': {'mean': 55.25173666322929, 'std': 3.152756181679028},
#  'nihtbx_cardsort_uncorrected': {'mean': 0.01902727147573316,
#   'std': 0.92710655806542},
#  'nihtbx_cryst_uncorrected': {'mean': 0.007018628014748754,
#   'std': 0.7845373584638602},
#  'nihtbx_flanker_uncorrected': {'mean': 0.02188780794049048,
#   'std': 0.9070917080607726},
#  'nihtbx_fluidcomp_uncorrected': {'mean': 0.020178243913565427,
#   'std': 0.86606123778624},
#  'nihtbx_list_uncorrected': {'mean': 0.00625176016120734,
#   'std': 0.8898550695735616},
#  'nihtbx_pattern_uncorrected': {'mean': 0.020721412569885096,
#   'std': 0.9486618556882954},
#  'nihtbx_picture_uncorrected': {'mean': 0.0005782175223803825,
#   'std': 0.9577989703304521},
#  'nihtbx_picvocab_uncorrected': {'mean': 0.0068509109986280275,
#   'std': 0.8038465951211212},
#  'nihtbx_reading_uncorrected': {'mean': 0.0027847502208883574,
#   'std': 0.8572703419965433},
#  'nihtbx_totalcomp_uncorrected': {'mean': 0.016971206631452577,
#   'std': 0.7866686549175077},
#  'vol': {'mean': 0.013939557398902416, 'std': 1.001699783217792},
#  'weight': {'mean': 81.91536668875837, 'std': 23.321845390211728}}

# %%
cat_cols = {'female': 2, 'race.ethnicity': 5, 'high.educ_group': 4, 'income_group': 8, 'married': 6}
num_cols = [x for x in list(val_df.columns) if '_norm' in x]

# %%
def calc_loss_acc(out_loss, out_acc, y_true, y_pred, cat_cols, num_cols, norm_dict):
  for col in num_cols:
    tmp_col = col
    tmp_std = norm_dict[tmp_col.replace('_norm','')]['std']
    tmp_y_true = tf.cast(y_true[col], tf.float32).numpy()
    tmp_y_pred = np.squeeze(y_pred[col].numpy())
    if not(tmp_col in out_loss):
      out_loss[tmp_col] = np.sum(np.square(tmp_y_true-tmp_y_pred))
    else:
      out_loss[tmp_col] += np.sum(np.square(tmp_y_true-tmp_y_pred))
    if not(tmp_col in out_acc):
      out_acc[tmp_col] = np.sum(np.square((tmp_y_true-tmp_y_pred)*tmp_std))
    else:
      out_acc[tmp_col] += np.sum(np.square((tmp_y_true-tmp_y_pred)*tmp_std))
  for col in list(cat_cols.keys()):
    tmp_col = col
    if not(tmp_col in out_loss):
      out_loss[tmp_col] = tf.keras.losses.SparseCategoricalCrossentropy()(tf.squeeze(y_true[col]), tf.squeeze(y_pred[col])).numpy()
    else:
      out_loss[tmp_col] += tf.keras.losses.SparseCategoricalCrossentropy()(tf.squeeze(y_true[col]), tf.squeeze(y_pred[col])).numpy()
    if not(tmp_col in out_acc):
      out_acc[tmp_col] = tf.reduce_sum(tf.dtypes.cast((y_true[col] == tf.argmax(y_pred[col], axis=-1)), tf.float32)).numpy()
    else:
      out_acc[tmp_col] += tf.reduce_sum(tf.dtypes.cast((y_true[col] == tf.argmax(y_pred[col], axis=-1)), tf.float32)).numpy()    
  return(out_loss, out_acc)

def format_output(out_loss, out_acc, n, cols, print_bl=False):
  loss = 0
  acc = 0
  output = []
  for col in cols:
    output.append([col, out_loss[col]/n, out_acc[col]/n])
    loss += out_loss[col]/n
    acc += out_acc[col]/n
  df = pd.DataFrame(output)
  df.columns = ['name', 'loss', 'acc']
  if print_bl:
    print(df)
  return(loss, acc, df)

@tf.function
def train_step(X, y, model, optimizer, cat_cols, num_cols):
  with tf.GradientTape() as tape:
    predictions = model(X)
    i = 0
    loss = tf.keras.losses.MSE(tf.cast(y[num_cols[i]], tf.float32), tf.squeeze(predictions[num_cols[i]]))
    for i in range(1,len(num_cols)):
      loss += tf.keras.losses.MSE(tf.cast(y[num_cols[i]], tf.float32), tf.squeeze(predictions[num_cols[i]]))
    for col in list(cat_cols.keys()):
      loss += tf.keras.losses.SparseCategoricalCrossentropy()(tf.squeeze(y[col]), tf.squeeze(predictions[col]))
  gradients = tape.gradient(loss, model.trainable_variables)
  mean_std = [x.name for x in model.non_trainable_variables if ('batch_norm') in x.name and ('mean' in x.name or 'variance' in x.name)]
  with tf.control_dependencies(mean_std):
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
  return(y, predictions, loss)

@tf.function
def test_step(X, y, model):
  predictions = model(X)
  return(y, predictions)

def epoch(data_iter, df, model, optimizer, cat_cols, num_cols, norm_dict):
  out_loss = {}
  out_acc = {}
  n = 0.
  n_batch = 0.
  total_time_dataload = 0.
  total_time_model = 0.
  start_time = time.time()
  for batch in data_iter:
    total_time_dataload += time.time() - start_time
    start_time = time.time()
    t1 = (tf.cast(batch['t1'], tf.float32)-t1_mean)/t1_std
    t2 = (batch['t2']-t2_mean)/t2_std
    if False:
        ad = batch['ad']
        ad = tf.where(tf.math.is_nan(ad), tf.zeros_like(ad), ad)
        ad = (ad-ad_mean)/ad_std
        fa = batch['fa']
        fa = tf.where(tf.math.is_nan(fa), tf.zeros_like(fa), fa)
        fa = (fa-fa_mean)/fa_std
        md = batch['md']
        md = tf.where(tf.math.is_nan(md), tf.zeros_like(md), md)
        md = (md-md_mean)/md_std
        rd = batch['rd']
        rd = tf.where(tf.math.is_nan(rd), tf.zeros_like(rd), rd)
        rd = (rd-rd_mean)/rd_std
    subjectid = decoder(batch['subjectid'])
    y = get_labels(df, subjectid, list(cat_cols.keys())+num_cols)
    #X = tf.concat([t1], axis=4)
    X = tf.concat([t1, t2], axis=4)
    if optimizer != None:
      y_true, y_pred, loss = train_step(X, y, model, optimizer, cat_cols, num_cols)
    else:
      y_true, y_pred = test_step(X, y, model)
    out_loss, out_acc = calc_loss_acc(out_loss, out_acc, y_true, y_pred, cat_cols, num_cols, norm_dict)
    n += X.shape[0]
    n_batch += 1
    if (n_batch % 10) == 0:
      log_textfile(path_output + modelname + '/log' + '.log', str(n_batch))
    total_time_model += time.time() - start_time
    start_time = time.time()
  return (out_loss, out_acc, n, total_time_model, total_time_dataload)

def get_labels(df, subjectid, cols = ['nihtbx_fluidcomp_uncorrected_norm']):
  subjects_df = pd.DataFrame(subjectid)
  result_df = pd.merge(subjects_df, df, left_on=0, right_on='subjectkey', how='left')
  output = {}
  for col in cols:
    output[col] = np.asarray(result_df[col].values)
  return output

def best_val(df_best, df_val, df_test, e):
  df_best = pd.merge(df_best, df_val, how='left', left_on='name', right_on='name')
  df_best = pd.merge(df_best, df_test, how='left', left_on='name', right_on='name')
  df_best.loc[df_best['best_loss_val']>=df_best['cur_loss_val'], 'best_loss_epochs'] = e
  df_best.loc[(df_best['best_acc_val']<=df_best['cur_acc_val'])&(df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'best_acc_epochs'] = e
  df_best.loc[df_best['best_loss_val']>=df_best['cur_loss_val'], 'best_loss_test'] = df_best.loc[df_best['best_loss_val']>=df_best['cur_loss_val'], 'cur_loss_test']
  df_best.loc[df_best['best_loss_val']>=df_best['cur_loss_val'], 'best_loss_val'] = df_best.loc[df_best['best_loss_val']>=df_best['cur_loss_val'], 'cur_loss_val']
  df_best.loc[(df_best['best_acc_val']<=df_best['cur_acc_val'])&(df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'best_acc_test'] = df_best.loc[(df_best['best_acc_val']<=df_best['cur_acc_val'])&(df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'cur_acc_test']
  df_best.loc[(df_best['best_acc_val']<=df_best['cur_acc_val'])&(df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'best_acc_val'] = df_best.loc[(df_best['best_acc_val']<=df_best['cur_acc_val'])&(df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'cur_acc_val']
  df_best.loc[(df_best['best_acc_val']>=df_best['cur_acc_val'])&(~df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'best_acc_test'] = df_best.loc[(df_best['best_acc_val']>=df_best['cur_acc_val'])&(~df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'cur_acc_test']
  df_best.loc[(df_best['best_acc_val']>=df_best['cur_acc_val'])&(~df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'best_acc_val'] = df_best.loc[(df_best['best_acc_val']>=df_best['cur_acc_val'])&(~df_best['name'].isin(['female', 'race.ethnicity', 'high.educ_group', 'income_group', 'married'])), 'cur_acc_val']
  df_best = df_best.drop(['cur_loss_val', 'cur_acc_val', 'cur_loss_test', 'cur_acc_test'], axis=1)
  return(df_best)

# %%
decoder = np.vectorize(lambda x: x.decode('UTF-8'))
template = 'Epoch {0}, Loss: {1:.3f}, Accuracy: {2:.3f}, Val Loss: {3:.3f}, Val Accuracy: {4:.3f}, Time Model: {5:.3f}, Time Data: {6:.3f}'
for col in [0]:
  log_textfile(path_output + modelname + '/log' + '.log', cat_cols)
  log_textfile(path_output + modelname + '/log' + '.log', num_cols)
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
  optimizer = tf.keras.optimizers.Adam(lr = 0.001)
  model = Model(cat_cols, num_cols)
  df_best = None
  for e in range(20):
    log_textfile(path_output + modelname + '/log' + '.log', 'Epochs: ' + str(e))
    loss = tf.Variable(0.)
    acc = tf.Variable(0.) 
    val_loss = tf.Variable(0.)
    val_acc = tf.Variable(0.)
    test_loss = tf.Variable(0.)
    test_acc = tf.Variable(0.)
    tf.keras.backend.set_learning_phase(True)
    train_out_loss, train_out_acc, n, time_model, time_data = epoch(train_iter, train_df, model, optimizer, cat_cols, num_cols, norm_dict)
    tf.keras.backend.set_learning_phase(False)
    val_out_loss, val_out_acc, n, _, _ = epoch(val_iter, val_df, model, None, cat_cols, num_cols, norm_dict)
    test_out_loss, test_out_acc, n, _, _ = epoch(test_iter, test_df, model, None, cat_cols, num_cols, norm_dict)
    loss, acc, _ = format_output(train_out_loss, train_out_acc, n, list(cat_cols.keys())+num_cols)
    val_loss, val_acc, df_val = format_output(val_out_loss, val_out_acc, n, list(cat_cols.keys())+num_cols, print_bl=False)
    test_loss, test_acc, df_test = format_output(test_out_loss, test_out_acc, n, list(cat_cols.keys())+num_cols, print_bl=False)
    df_val.columns = ['name', 'cur_loss_val', 'cur_acc_val']
    df_test.columns = ['name', 'cur_loss_test', 'cur_acc_test']
    if e == 0:
      df_best = pd.merge(df_test, df_val, how='left', left_on='name', right_on='name')
      df_best['best_acc_epochs'] = 0
      df_best['best_loss_epochs'] = 0
      df_best.columns = ['name', 'best_loss_test', 'best_acc_test', 'best_loss_val', 'best_acc_val', 'best_acc_epochs', 'best_loss_epochs']
    df_best = best_val(df_best, df_val, df_test, e)
    print(df_best[['name', 'best_loss_test', 'best_acc_test']])
    print(df_best[['name', 'best_loss_val', 'best_acc_val']])
    log_textfile(path_output + modelname + '/log' + '.log', template.format(e, loss, acc, val_loss, val_acc, time_model, time_data))
    if e in [10, 15]:
      optimizer.lr = optimizer.lr/3
      log_textfile(path_output + modelname + '/log' + '.log', 'Learning rate: ' + str(optimizer.lr))
    df_best.to_csv(path_output +  modelname + '/df_best' + str(e) + '.csv')
    df_best.to_csv(path_output +  modelname + '/df_best' + '.csv')
    #model.save_weights(path_output + modelname + '/checkpoints/' + str(e) + '/')
# Out:
# {'female': 2, 'high.educ_group': 4, 'income_group': 8, 'married': 6, 'race.ethnicity': 5}
# ['BMI_norm', 'age_norm', 'vol_norm', 'weight_norm', 'height_norm', 'nihtbx_fluidcomp_uncorrected_norm', 'nihtbx_cryst_uncorrected_norm', 'nihtbx_pattern_uncorrected_norm', 'nihtbx_picture_uncorrected_norm', 'nihtbx_list_uncorrected_norm', 'nihtbx_flanker_uncorrected_norm', 'nihtbx_picvocab_uncorrected_norm', 'nihtbx_cardsort_uncorrected_norm', 'nihtbx_totalcomp_uncorrected_norm', 'nihtbx_reading_uncorrected_norm']
# Epochs: 0
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.140657       0.912500
# 1                              female        0.088744       0.475000
# 2                        income_group        0.259837       0.037500
# 3                             married        0.215375       0.125000
# 4                      race.ethnicity        0.186981       0.537500
# 5                            BMI_norm        1.120331      19.697226
# 6                            age_norm        1.102373      61.663867
# 7                            vol_norm        0.998468       1.001866
# 8                         weight_norm        0.982398     534.334473
# 9                         height_norm        1.235117      12.276910
# 10  nihtbx_fluidcomp_uncorrected_norm       13.073691       9.806079
# 11      nihtbx_cryst_uncorrected_norm        6.005745       3.696530
# 12    nihtbx_pattern_uncorrected_norm       17.717587      15.945108
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        4.611946       3.651933
# 15    nihtbx_flanker_uncorrected_norm       25.978195      21.375258
# 16   nihtbx_picvocab_uncorrected_norm       18.036456      11.654604
# 17   nihtbx_cardsort_uncorrected_norm        2.372182       2.038953
# 18  nihtbx_totalcomp_uncorrected_norm        4.477837       2.771099
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.142056      0.887500
# 1                              female       0.085804      0.550000
# 2                        income_group       0.258671      0.075000
# 3                             married       0.214140      0.112500
# 4                      race.ethnicity       0.184361      0.625000
# 5                            BMI_norm       0.398408      7.004647
# 6                            age_norm       0.904718     50.607578
# 7                            vol_norm       0.766704      0.769313
# 8                         weight_norm       0.537767    292.496216
# 9                         height_norm       1.037891     10.316505
# 10  nihtbx_fluidcomp_uncorrected_norm      13.131233      9.849240
# 11      nihtbx_cryst_uncorrected_norm       6.936388      4.269339
# 12    nihtbx_pattern_uncorrected_norm      16.581932     14.923064
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       4.271064      3.382008
# 15    nihtbx_flanker_uncorrected_norm      24.493042     20.153252
# 16   nihtbx_picvocab_uncorrected_norm      19.034174     12.299300
# 17   nihtbx_cardsort_uncorrected_norm       2.067881      1.777398
# 18  nihtbx_totalcomp_uncorrected_norm       4.703318      2.910637
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 0, Loss: 30.916, Accuracy: 782.101, Val Loss: 98.727, Val Accuracy: 435.496, Time Model: 14.728, Time Data: 0.397
# Epochs: 1
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.136112       0.912500
# 1                              female        0.088744       0.475000
# 2                        income_group        0.254390       0.325000
# 3                             married        0.195139       0.737500
# 4                      race.ethnicity        0.182176       0.537500
# 5                            BMI_norm        1.120331      19.697226
# 6                            age_norm        1.102373      61.663867
# 7                            vol_norm        0.998468       1.001866
# 8                         weight_norm        1.043824     567.744824
# 9                         height_norm        1.235117      12.276910
# 10  nihtbx_fluidcomp_uncorrected_norm        2.686936       2.015369
# 11      nihtbx_cryst_uncorrected_norm        1.988986       1.224219
# 12    nihtbx_pattern_uncorrected_norm       17.717587      15.945108
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        4.611946       3.651933
# 15    nihtbx_flanker_uncorrected_norm       25.978195      21.375258
# 16   nihtbx_picvocab_uncorrected_norm        8.747514       5.652375
# 17   nihtbx_cardsort_uncorrected_norm        2.372182       2.038953
# 18  nihtbx_totalcomp_uncorrected_norm        4.477837       2.771099
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.137673      0.887500
# 1                              female       0.085804      0.550000
# 2                        income_group       0.252167      0.362500
# 3                             married       0.193241      0.775000
# 4                      race.ethnicity       0.179258      0.625000
# 5                            BMI_norm       0.398408      7.004647
# 6                            age_norm       0.904718     50.607578
# 7                            vol_norm       0.766704      0.769313
# 8                         weight_norm       0.522014    283.927734
# 9                         height_norm       1.037891     10.316505
# 10  nihtbx_fluidcomp_uncorrected_norm       2.184450      1.638473
# 11      nihtbx_cryst_uncorrected_norm       1.564855      0.963167
# 12    nihtbx_pattern_uncorrected_norm      16.581932     14.923064
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       4.271064      3.382008
# 15    nihtbx_flanker_uncorrected_norm      24.493042     20.153252
# 16   nihtbx_picvocab_uncorrected_norm       9.470979      6.119856
# 17   nihtbx_cardsort_uncorrected_norm       2.067881      1.777398
# 18  nihtbx_totalcomp_uncorrected_norm       4.703318      2.910637
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 1, Loss: 21.658, Accuracy: 770.788, Val Loss: 216.388, Val Accuracy: 529.126, Time Model: 1.627, Time Data: 0.417
# Epochs: 2
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.122537       0.912500
# 1                              female        0.088744       0.475000
# 2                        income_group        0.254619       0.325000
# 3                             married        0.177012       0.737500
# 4                      race.ethnicity        0.175706       0.537500
# 5                            BMI_norm        1.120331      19.697226
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.998468       1.001866
# 8                         weight_norm        1.037506     564.308203
# 9                         height_norm        1.129164      11.223743
# 10  nihtbx_fluidcomp_uncorrected_norm        2.686936       2.015369
# 11      nihtbx_cryst_uncorrected_norm        1.988986       1.224219
# 12    nihtbx_pattern_uncorrected_norm       16.372174      14.734291
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        4.611946       3.651933
# 15    nihtbx_flanker_uncorrected_norm       17.046371      14.026018
# 16   nihtbx_picvocab_uncorrected_norm        8.747514       5.652375
# 17   nihtbx_cardsort_uncorrected_norm        2.372182       2.038953
# 18  nihtbx_totalcomp_uncorrected_norm        4.477837       2.771099
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.124718      0.887500
# 1                              female       0.085804      0.550000
# 2                        income_group       0.251993      0.362500
# 3                             married       0.173186      0.775000
# 4                      race.ethnicity       0.170160      0.625000
# 5                            BMI_norm       0.398408      7.004647
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.766704      0.769313
# 8                         weight_norm       0.513094    279.076440
# 9                         height_norm       0.966971      9.611565
# 10  nihtbx_fluidcomp_uncorrected_norm       2.184450      1.638473
# 11      nihtbx_cryst_uncorrected_norm       1.564855      0.963167
# 12    nihtbx_pattern_uncorrected_norm      15.007672     13.506296
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       4.271064      3.382008
# 15    nihtbx_flanker_uncorrected_norm      15.814276     13.012230
# 16   nihtbx_picvocab_uncorrected_norm       9.470979      6.119856
# 17   nihtbx_cardsort_uncorrected_norm       2.067881      1.777398
# 18  nihtbx_totalcomp_uncorrected_norm       4.703318      2.910637
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 2, Loss: 19.583, Accuracy: 710.056, Val Loss: 179.106, Val Accuracy: 485.865, Time Model: 1.651, Time Data: 0.406
# Epochs: 3
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.109375       0.912500
# 1                              female        0.088744       0.475000
# 2                        income_group        0.249105       0.337500
# 3                             married        0.167526       0.737500
# 4                      race.ethnicity        0.172175       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.998468       1.001866
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.129164      11.223743
# 10  nihtbx_fluidcomp_uncorrected_norm        1.330234       0.997758
# 11      nihtbx_cryst_uncorrected_norm        1.988986       1.224219
# 12    nihtbx_pattern_uncorrected_norm        3.609840       3.248709
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        4.611946       3.651933
# 15    nihtbx_flanker_uncorrected_norm        2.876575       2.366891
# 16   nihtbx_picvocab_uncorrected_norm        2.799864       1.809186
# 17   nihtbx_cardsort_uncorrected_norm        2.372182       2.038953
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.112161      0.887500
# 1                              female       0.085804      0.550000
# 2                        income_group       0.246499      0.362500
# 3                             married       0.162698      0.775000
# 4                      race.ethnicity       0.165965      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.766704      0.769313
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.966971      9.611565
# 10  nihtbx_fluidcomp_uncorrected_norm       1.371202      1.028487
# 11      nihtbx_cryst_uncorrected_norm       1.564855      0.963167
# 12    nihtbx_pattern_uncorrected_norm       3.203579      2.883091
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       4.271064      3.382008
# 15    nihtbx_flanker_uncorrected_norm       2.697390      2.219454
# 16   nihtbx_picvocab_uncorrected_norm       3.073629      1.986085
# 17   nihtbx_cardsort_uncorrected_norm       2.067881      1.777398
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 3, Loss: 16.024, Accuracy: 494.918, Val Loss: 48.283, Val Accuracy: 383.465, Time Model: 1.644, Time Data: 0.402
# Epochs: 4
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.090973       0.912500
# 1                              female        0.088744       0.475000
# 2                        income_group        0.245390       0.337500
# 3                             married        0.156218       0.737500
# 4                      race.ethnicity        0.168136       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.982017       0.985358
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.129164      11.223743
# 10  nihtbx_fluidcomp_uncorrected_norm        1.330234       0.997758
# 11      nihtbx_cryst_uncorrected_norm        1.524637       0.938412
# 12    nihtbx_pattern_uncorrected_norm        3.609840       3.248709
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        2.876575       2.366891
# 16   nihtbx_picvocab_uncorrected_norm        2.264788       1.463437
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.094811      0.887500
# 1                              female       0.085804      0.550000
# 2                        income_group       0.242024      0.362500
# 3                             married       0.150602      0.775000
# 4                      race.ethnicity       0.160285      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.755073      0.757642
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.966971      9.611565
# 10  nihtbx_fluidcomp_uncorrected_norm       1.371202      1.028487
# 11      nihtbx_cryst_uncorrected_norm       1.271648      0.782698
# 12    nihtbx_pattern_uncorrected_norm       3.203579      2.883091
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       2.697390      2.219454
# 16   nihtbx_picvocab_uncorrected_norm       1.465114      0.946712
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 4, Loss: 17.817, Accuracy: 489.177, Val Loss: 50.990, Val Accuracy: 396.819, Time Model: 1.646, Time Data: 0.400
# Epochs: 5
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.078172       0.912500
# 1                              female        0.088393       0.475000
# 2                        income_group        0.242083       0.337500
# 3                             married        0.148158       0.737500
# 4                      race.ethnicity        0.165744       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.979684       0.983018
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.095169      10.885838
# 10  nihtbx_fluidcomp_uncorrected_norm        1.143795       0.857917
# 11      nihtbx_cryst_uncorrected_norm        1.524637       0.938412
# 12    nihtbx_pattern_uncorrected_norm        2.568532       2.311574
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        2.032504       1.672376
# 16   nihtbx_picvocab_uncorrected_norm        1.520052       0.982211
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.082725      0.887500
# 1                              female       0.085726      0.550000
# 2                        income_group       0.237869      0.362500
# 3                             married       0.142449      0.775000
# 4                      race.ethnicity       0.156489      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.751933      0.754492
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.951493      9.457720
# 10  nihtbx_fluidcomp_uncorrected_norm       1.167467      0.875673
# 11      nihtbx_cryst_uncorrected_norm       1.271648      0.782698
# 12    nihtbx_pattern_uncorrected_norm       2.245534      2.020889
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       1.899582      1.563005
# 16   nihtbx_picvocab_uncorrected_norm       1.128974      0.729509
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 5, Loss: 16.186, Accuracy: 461.763, Val Loss: 31.317, Val Accuracy: 376.222, Time Model: 1.636, Time Data: 0.407
# Epochs: 6
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.067937       0.912500
# 1                              female        0.088393       0.475000
# 2                        income_group        0.240031       0.337500
# 3                             married        0.142784       0.737500
# 4                      race.ethnicity        0.164318       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.964391       0.967672
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.081499      10.749961
# 10  nihtbx_fluidcomp_uncorrected_norm        1.190441       0.892905
# 11      nihtbx_cryst_uncorrected_norm        1.379638       0.849166
# 12    nihtbx_pattern_uncorrected_norm        1.664172       1.497687
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        1.109198       0.912665
# 16   nihtbx_picvocab_uncorrected_norm        1.520052       0.982211
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.676614       1.232165
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.073189      0.887500
# 1                              female       0.085726      0.550000
# 2                        income_group       0.235314      0.362500
# 3                             married       0.136156      0.775000
# 4                      race.ethnicity       0.153049      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.739384      0.741900
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.943277      9.376054
# 10  nihtbx_fluidcomp_uncorrected_norm       0.945730      0.709356
# 11      nihtbx_cryst_uncorrected_norm       1.226192      0.754720
# 12    nihtbx_pattern_uncorrected_norm       1.504008      1.353546
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       1.112174      0.915114
# 16   nihtbx_picvocab_uncorrected_norm       1.128974      0.729509
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.333432      0.979956
# Epoch 6, Loss: 14.620, Accuracy: 400.024, Val Loss: 20.858, Val Accuracy: 372.718, Time Model: 1.635, Time Data: 0.401
# Epochs: 7
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.062576       0.912500
# 1                              female        0.086952       0.475000
# 2                        income_group        0.238889       0.337500
# 3                             married        0.137782       0.737500
# 4                      race.ethnicity        0.163447       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.964391       0.967672
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.041347      10.350860
# 10  nihtbx_fluidcomp_uncorrected_norm        0.950422       0.712875
# 11      nihtbx_cryst_uncorrected_norm        1.379638       0.849166
# 12    nihtbx_pattern_uncorrected_norm        1.119561       1.007560
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        1.109198       0.912665
# 16   nihtbx_picvocab_uncorrected_norm        1.361706       0.879893
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.068688      0.887500
# 1                              female       0.085692      0.550000
# 2                        income_group       0.234368      0.362500
# 3                             married       0.130049      0.775000
# 4                      race.ethnicity       0.151405      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.739384      0.741900
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.921156      9.156174
# 10  nihtbx_fluidcomp_uncorrected_norm       0.880142      0.660161
# 11      nihtbx_cryst_uncorrected_norm       1.226192      0.754720
# 12    nihtbx_pattern_uncorrected_norm       1.130072      1.017019
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       1.112174      0.915114
# 16   nihtbx_picvocab_uncorrected_norm       1.104638      0.713783
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 7, Loss: 15.375, Accuracy: 439.899, Val Loss: 20.669, Val Accuracy: 374.979, Time Model: 1.663, Time Data: 0.400
# Epochs: 8
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.057049       0.912500
# 1                              female        0.087263       0.475000
# 2                        income_group        0.238452       0.337500
# 3                             married        0.136032       0.737500
# 4                      race.ethnicity        0.162334       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.949531       0.952761
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.041347      10.350860
# 10  nihtbx_fluidcomp_uncorrected_norm        1.037317       0.778052
# 11      nihtbx_cryst_uncorrected_norm        1.379638       0.849166
# 12    nihtbx_pattern_uncorrected_norm        1.119561       1.007560
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        1.109198       0.912665
# 16   nihtbx_picvocab_uncorrected_norm        1.361706       0.879893
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.063476      0.887500
# 1                              female       0.085398      0.550000
# 2                        income_group       0.232851      0.362500
# 3                             married       0.128265      0.775000
# 4                      race.ethnicity       0.150170      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.737784      0.740295
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.921156      9.156174
# 10  nihtbx_fluidcomp_uncorrected_norm       0.875444      0.656637
# 11      nihtbx_cryst_uncorrected_norm       1.226192      0.754720
# 12    nihtbx_pattern_uncorrected_norm       1.130072      1.017019
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       1.112174      0.915114
# 16   nihtbx_picvocab_uncorrected_norm       1.104638      0.713783
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 8, Loss: 15.792, Accuracy: 373.493, Val Loss: 19.390, Val Accuracy: 371.912, Time Model: 1.657, Time Data: 0.385
# Epochs: 9
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.051780       0.912500
# 1                              female        0.087263       0.475000
# 2                        income_group        0.237302       0.337500
# 3                             married        0.132595       0.737500
# 4                      race.ethnicity        0.162070       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.944761       0.947976
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.039478      10.332278
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.379638       0.849166
# 12    nihtbx_pattern_uncorrected_norm        1.119561       1.007560
# 13    nihtbx_picture_uncorrected_norm        1.528679       1.402378
# 14       nihtbx_list_uncorrected_norm        1.193076       0.944728
# 15    nihtbx_flanker_uncorrected_norm        1.109198       0.912665
# 16   nihtbx_picvocab_uncorrected_norm        1.361706       0.879893
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.058998      0.887500
# 1                              female       0.085398      0.550000
# 2                        income_group       0.230410      0.362500
# 3                             married       0.123970      0.775000
# 4                      race.ethnicity       0.147040      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.733462      0.735958
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.919421      9.138922
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.226192      0.754720
# 12    nihtbx_pattern_uncorrected_norm       1.130072      1.017019
# 13    nihtbx_picture_uncorrected_norm       1.643616      1.507819
# 14       nihtbx_list_uncorrected_norm       0.548291      0.434160
# 15    nihtbx_flanker_uncorrected_norm       1.112174      0.915114
# 16   nihtbx_picvocab_uncorrected_norm       1.104638      0.713783
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 9, Loss: 14.672, Accuracy: 354.229, Val Loss: 19.102, Val Accuracy: 367.521, Time Model: 1.625, Time Data: 0.405
# Epochs: 10
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.049359       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.129856       0.737500
# 4                      race.ethnicity        0.161227       0.537500
# 5                            BMI_norm        1.098433      19.312215
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.944761       0.947976
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.344530       0.827556
# 12    nihtbx_pattern_uncorrected_norm        1.119561       1.007560
# 13    nihtbx_picture_uncorrected_norm        1.226736       1.125381
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        0.986023       0.811315
# 16   nihtbx_picvocab_uncorrected_norm        1.361706       0.879893
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.056936      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.120558      0.775000
# 4                      race.ethnicity       0.145093      0.625000
# 5                            BMI_norm       0.392891      6.907664
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.733462      0.735958
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.199519      0.738303
# 12    nihtbx_pattern_uncorrected_norm       1.130072      1.017019
# 13    nihtbx_picture_uncorrected_norm       1.180389      1.082864
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       1.043329      0.858467
# 16   nihtbx_picvocab_uncorrected_norm       1.104638      0.713783
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 10, Loss: 14.080, Accuracy: 301.325, Val Loss: 14.527, Val Accuracy: 366.240, Time Model: 1.649, Time Data: 0.416
# Learning rate: <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=0.00033333336>
# Epochs: 11
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.048818       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.129856       0.737500
# 4                      race.ethnicity        0.161227       0.537500
# 5                            BMI_norm        1.100366      19.346214
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.944761       0.947976
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.280894       1.152752
# 13    nihtbx_picture_uncorrected_norm        1.057659       0.970274
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        0.981929       0.807946
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.056330      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.120558      0.775000
# 4                      race.ethnicity       0.145093      0.625000
# 5                            BMI_norm       0.392358      6.898280
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.733462      0.735958
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.085875      0.977243
# 13    nihtbx_picture_uncorrected_norm       1.087970      0.998081
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       1.012617      0.833197
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 11, Loss: 13.856, Accuracy: 285.835, Val Loss: 14.048, Val Accuracy: 362.503, Time Model: 1.651, Time Data: 0.411
# Epochs: 12
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.048578       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.129342       0.737500
# 4                      race.ethnicity        0.161227       0.537500
# 5                            BMI_norm        1.085797      19.090068
# 6                            age_norm        1.141911      63.875513
# 7                            vol_norm        0.944761       0.947976
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.194229       1.074757
# 13    nihtbx_picture_uncorrected_norm        1.010158       0.926697
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.001800       0.824297
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.877193       0.753970
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.056183      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.119899      0.775000
# 4                      race.ethnicity       0.145093      0.625000
# 5                            BMI_norm       0.387445      6.811904
# 6                            age_norm       0.889749     49.770236
# 7                            vol_norm       0.733462      0.735958
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.045701      0.941088
# 13    nihtbx_picture_uncorrected_norm       1.051584      0.964701
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.985965      0.811267
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.900926      0.774369
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 12, Loss: 13.193, Accuracy: 308.888, Val Loss: 13.954, Val Accuracy: 361.547, Time Model: 1.633, Time Data: 0.415
# Epochs: 13
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.048158       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.128671       0.737500
# 4                      race.ethnicity        0.161227       0.537500
# 5                            BMI_norm        1.085797      19.090068
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.944761       0.947976
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.963495       0.883890
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.001800       0.824297
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.895149       0.769404
# 18  nihtbx_totalcomp_uncorrected_norm        1.312001       0.811929
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.055519      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.119138      0.775000
# 4                      race.ethnicity       0.145093      0.625000
# 5                            BMI_norm       0.387445      6.811904
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.733462      0.735958
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       1.029336      0.944291
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.985965      0.811267
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.890653      0.765540
# 18  nihtbx_totalcomp_uncorrected_norm       0.906205      0.560803
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 13, Loss: 13.224, Accuracy: 306.770, Val Loss: 13.852, Val Accuracy: 361.939, Time Model: 1.648, Time Data: 0.378
# Epochs: 14
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.047941       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.127489       0.737500
# 4                      race.ethnicity        0.161227       0.537500
# 5                            BMI_norm        1.088843      19.143622
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.921936       0.925073
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.938576       0.861030
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.009751       0.830838
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.856164       0.735895
# 18  nihtbx_totalcomp_uncorrected_norm        1.356379       0.839392
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.054955      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.117273      0.775000
# 4                      race.ethnicity       0.145093      0.625000
# 5                            BMI_norm       0.384752      6.764551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.726360      0.728831
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       1.005740      0.922645
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.979761      0.806162
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.860488      0.739612
# 18  nihtbx_totalcomp_uncorrected_norm       0.901512      0.557898
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 14, Loss: 12.589, Accuracy: 255.307, Val Loss: 13.807, Val Accuracy: 362.603, Time Model: 1.640, Time Data: 0.413
# Epochs: 15
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.047544       0.912500
# 1                              female        0.087263       0.575000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.126979       0.737500
# 4                      race.ethnicity        0.160985       0.537500
# 5                            BMI_norm        1.088843      19.143622
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.915398       0.918513
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.945887       0.867737
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.019497       0.838858
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.813780       0.699466
# 18  nihtbx_totalcomp_uncorrected_norm        1.335475       0.826455
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.054176      0.887500
# 1                              female       0.085398      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.116598      0.775000
# 4                      race.ethnicity       0.145014      0.625000
# 5                            BMI_norm       0.384752      6.764551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.722345      0.724803
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       0.989464      0.907713
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.959953      0.789864
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.836138      0.718683
# 18  nihtbx_totalcomp_uncorrected_norm       0.896022      0.554501
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 15, Loss: 12.383, Accuracy: 233.147, Val Loss: 13.771, Val Accuracy: 363.347, Time Model: 1.658, Time Data: 0.429
# Learning rate: <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=0.00011111112>
# Epochs: 16
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.047174       0.912500
# 1                              female        0.083887       0.662500
# 2                        income_group        0.237011       0.337500
# 3                             married        0.126071       0.737500
# 4                      race.ethnicity        0.161516       0.537500
# 5                            BMI_norm        1.088843      19.143622
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.901793       0.904861
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.943541       0.865585
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.024168       0.842701
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.799712       0.687374
# 18  nihtbx_totalcomp_uncorrected_norm        1.335475       0.826455
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.053699      0.887500
# 1                              female       0.084992      0.575000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.115463      0.775000
# 4                      race.ethnicity       0.144537      0.625000
# 5                            BMI_norm       0.384752      6.764551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.715061      0.717494
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       0.982138      0.900993
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.956217      0.786790
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.833078      0.716053
# 18  nihtbx_totalcomp_uncorrected_norm       0.896022      0.554501
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 16, Loss: 12.152, Accuracy: 208.106, Val Loss: 13.748, Val Accuracy: 364.203, Time Model: 1.640, Time Data: 0.405
# Epochs: 17
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.046942       0.912500
# 1                              female        0.083670       0.625000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.125360       0.737500
# 4                      race.ethnicity        0.162099       0.537500
# 5                            BMI_norm        1.088843      19.143622
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.898989       0.902048
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.934194       0.857009
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.024820       0.843238
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.774784       0.665947
# 18  nihtbx_totalcomp_uncorrected_norm        1.335475       0.826455
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.053353      0.887500
# 1                              female       0.084552      0.625000
# 2                        income_group       0.230075      0.362500
# 3                             married       0.114468      0.775000
# 4                      race.ethnicity       0.144363      0.625000
# 5                            BMI_norm       0.384752      6.764551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.715043      0.717476
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       0.975782      0.895162
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.954662      0.785511
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.829405      0.712896
# 18  nihtbx_totalcomp_uncorrected_norm       0.896022      0.554501
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 17, Loss: 11.897, Accuracy: 219.722, Val Loss: 13.762, Val Accuracy: 364.342, Time Model: 1.637, Time Data: 0.411
# Epochs: 18
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.046889       0.912500
# 1                              female        0.083362       0.625000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.124914       0.737500
# 4                      race.ethnicity        0.162099       0.537500
# 5                            BMI_norm        1.103555      19.402272
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.898989       0.902048
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.913887       0.838381
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.024820       0.843238
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.756506       0.650237
# 18  nihtbx_totalcomp_uncorrected_norm        1.335475       0.826455
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.053207      0.887500
# 1                              female       0.084222      0.637500
# 2                        income_group       0.230075      0.362500
# 3                             married       0.113823      0.775000
# 4                      race.ethnicity       0.144363      0.625000
# 5                            BMI_norm       0.383785      6.747551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.715043      0.717476
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       0.965375      0.885615
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.954662      0.785511
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.826514      0.710411
# 18  nihtbx_totalcomp_uncorrected_norm       0.896022      0.554501
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 18, Loss: 12.202, Accuracy: 197.947, Val Loss: 13.863, Val Accuracy: 365.987, Time Model: 1.636, Time Data: 0.394
# Epochs: 19
# 10.0
# 10.0
# 10.0
#                                  name  best_loss_test  best_acc_test
# 0                     high.educ_group        0.046588       0.912500
# 1                              female        0.083260       0.625000
# 2                        income_group        0.237011       0.337500
# 3                             married        0.123976       0.737500
# 4                      race.ethnicity        0.162099       0.537500
# 5                            BMI_norm        1.103555      19.402272
# 6                            age_norm        1.158518      64.804456
# 7                            vol_norm        0.888913       0.891938
# 8                         weight_norm        1.051972     572.176660
# 9                         height_norm        1.021789      10.156449
# 10  nihtbx_fluidcomp_uncorrected_norm        0.988832       0.741685
# 11      nihtbx_cryst_uncorrected_norm        1.279173       0.787330
# 12    nihtbx_pattern_uncorrected_norm        1.124540       1.012040
# 13    nihtbx_picture_uncorrected_norm        0.913887       0.838381
# 14       nihtbx_list_uncorrected_norm        1.174047       0.929660
# 15    nihtbx_flanker_uncorrected_norm        1.024820       0.843238
# 16   nihtbx_picvocab_uncorrected_norm        1.482817       0.958151
# 17   nihtbx_cardsort_uncorrected_norm        0.756506       0.650237
# 18  nihtbx_totalcomp_uncorrected_norm        1.335475       0.826455
# 19    nihtbx_reading_uncorrected_norm        1.197951       0.880389
#                                  name  best_loss_val  best_acc_val
# 0                     high.educ_group       0.053029      0.887500
# 1                              female       0.083783      0.637500
# 2                        income_group       0.230075      0.362500
# 3                             married       0.112271      0.775000
# 4                      race.ethnicity       0.144363      0.625000
# 5                            BMI_norm       0.383785      6.747551
# 6                            age_norm       0.886955     49.613965
# 7                            vol_norm       0.707056      0.709462
# 8                         weight_norm       0.507259    275.902637
# 9                         height_norm       0.909174      9.037070
# 10  nihtbx_fluidcomp_uncorrected_norm       0.859768      0.644880
# 11      nihtbx_cryst_uncorrected_norm       1.189900      0.732382
# 12    nihtbx_pattern_uncorrected_norm       1.020105      0.918053
# 13    nihtbx_picture_uncorrected_norm       0.965375      0.885615
# 14       nihtbx_list_uncorrected_norm       0.521093      0.412624
# 15    nihtbx_flanker_uncorrected_norm       0.954662      0.785511
# 16   nihtbx_picvocab_uncorrected_norm       1.099597      0.710526
# 17   nihtbx_cardsort_uncorrected_norm       0.826514      0.710411
# 18  nihtbx_totalcomp_uncorrected_norm       0.896022      0.554501
# 19    nihtbx_reading_uncorrected_norm       1.091563      0.802204
# Epoch 19, Loss: 12.293, Accuracy: 203.168, Val Loss: 13.934, Val Accuracy: 369.462, Time Model: 1.628, Time Data: 0.374

# %%
error

# %%
test_loss, test_acc, df_test = format_output(test_out_loss, test_out_acc, n, list(cat_cols.keys())+num_cols, print_bl=False)

# %%
df_test.to_csv('final_output_all.csv')

# %%
inputs = tf.keras.Input(shape=(64,64,64,2), name='inputlayer123')
a = model(inputs)['female']
mm = tf.keras.models.Model(inputs=inputs, outputs=a)

# %%
from tf_explain.core.smoothgrad import SmoothGrad
import pickle

explainer = SmoothGrad()
output_grid = {}
output_n = {}
for i in range(2):
  output_grid[i] = np.zeros((64,64,64))
  output_n[i] = 0
counter = 0
for batch in test_iter:
  counter+=1
  print(counter)
  t1 = (tf.cast(batch['t1'], tf.float32)-t1_mean)/t1_std
  t2 = (batch['t2']-t2_mean)/t2_std
  X = tf.concat([t1, t2], axis=4)
  subjectid = decoder(batch['subjectid'])
  y = get_labels(test_df, subjectid, list(cat_cols.keys())+num_cols)
  y_list = list(y['female'])
  for i in range(X.shape[0]):
    X_i = X[i]
    X_i = tf.expand_dims(X_i, axis=0)
    y_i = y_list[i]
    grid = explainer.explain((X_i, _), mm, y_i, 20, 1.)
    output_grid[y_i] += grid
    output_n[y_i] += 1
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-3e4e8f80ca55> in <module>
#      22     X_i = tf.expand_dims(X_i, axis=0)
#      23     y_i = y_list[i]
# ---> 24     grid = explainer.explain((X_i, _), mm, y_i, 20, 1.)
#      25     output_grid[y_i] += grid
#      26     output_n[y_i] += 1
#
# ~/.local/lib/python3.5/site-packages/tf_explain/core/smoothgrad.py in explain(self, validation_data, model, class_index, num_samples, noise)
#      43
#      44         grayscale_gradients = SmoothGrad.transform_to_grayscale(
# ---> 45             smoothed_gradients
#      46         ).numpy()
#      47
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/framework/ops.py in numpy(self)
#     931       ValueError: if the type of this Tensor is not representable in numpy.
#     932     """
# --> 933     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     934     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     935
#
# KeyboardInterrupt:

# %%
pickle.dump([output_grid, output_n], open( "smoothgrad_female_all.p", "wb" ) )

# %%
#output_grid, output_n = pickle.load(open( "smoothgrad_female.p", "rb" ))

# %%
def apply_grey_patch(image, top_left_x, top_left_y, top_left_z, patch_size):
    """
    Replace a part of the image with a grey patch.
    Args:
        image (numpy.ndarray): Input image
        top_left_x (int): Top Left X position of the applied box
        top_left_y (int): Top Left Y position of the applied box
        patch_size (int): Size of patch to apply
    Returns:
        numpy.ndarray: Patched image
    """
    patched_image = np.array(image, copy=True)
    patched_image[
        top_left_x : top_left_x + patch_size, top_left_y : top_left_y + patch_size, top_left_z : top_left_z + patch_size, :
    ] = 0

    return patched_image

# %%
import math

# %%
def get_sensgrid(image, mm, class_index, patch_size):
  sensitivity_map = np.zeros((
    math.ceil(image.shape[0] / patch_size),
    math.ceil(image.shape[1] / patch_size),
    math.ceil(image.shape[2] / patch_size)
  ))
  for index_z, top_left_z in enumerate(range(0, image.shape[2], patch_size)):
    patches = [
              apply_grey_patch(image, top_left_x, top_left_y, top_left_z, patch_size)
              for index_x, top_left_x in enumerate(range(0, image.shape[0], patch_size))
              for index_y, top_left_y in enumerate(range(0, image.shape[1], patch_size))
              ]
    coordinates = [
                (index_y, index_x)
                for index_x, _ in enumerate(range(0, image.shape[0], patch_size))
                for index_y, _ in enumerate(range(0, image.shape[1], patch_size))
                ]
    predictions = mm.predict(np.array(patches), batch_size=1)
    target_class_predictions = [prediction[class_index] for prediction in predictions]
    for (index_y, index_x), confidence in zip(coordinates, target_class_predictions):
      sensitivity_map[index_y, index_x, index_z] = 1 - confidence
  sm = resize(sensitivity_map, (64,64,64))
  heatmap = (sm - np.min(sm)) / (sm.max() - sm.min())
  return(heatmap)

# %%
output_grid = {}
output_n = {}
for i in range(2):
  output_grid[i] = np.zeros((64,64,64))
  output_n[i] = 0

counter = 0
for batch in test_iter:
  counter+=1
  print(counter)
  t1 = (tf.cast(batch['t1'], tf.float32)-t1_mean)/t1_std
  t2 = (batch['t2']-t2_mean)/t2_std
  X = tf.concat([t1, t2], axis=4)
  subjectid = decoder(batch['subjectid'])
  y = get_labels(test_df, subjectid, list(cat_cols.keys())+num_cols)
  y_list = list(y['female'])
  for i in range(X.shape[0]):
    print(i)
    X_i = X[i]
    y_i = y_list[i]
    grid = get_sensgrid(X_i, mm, y_i, 4)
    output_grid[y_i] += grid
    output_n[y_i] += 1
  if counter==6:
    break
# Out:
# 1
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-24ce84852ea7> in <module>
#      19     X_i = X[i]
#      20     y_i = y_list[i]
# ---> 21     grid = get_sensgrid(X_i, mm, y_i, 4)
#      22     output_grid[y_i] += grid
#      23     output_n[y_i] += 1
#
# <ipython-input-27-a314f14433ab> in get_sensgrid(image, mm, class_index, patch_size)
#      20     for (index_y, index_x), confidence in zip(coordinates, target_class_predictions):
#      21       sensitivity_map[index_y, index_x, index_z] = 1 - confidence
# ---> 22   sm = resize(sensitivity_map, (64,64,64))
#      23   heatmap = (sm - np.min(sm)) / (sm.max() - sm.min())
#      24   return(heatmap)
#
# NameError: name 'resize' is not defined

# %%
pickle.dump([output_grid, output_n], open( "heatmap_female_all.p", "wb" ) )

# %%
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ded28046d863> in <module>
# ----> 1 error
#
# NameError: name 'error' is not defined

# %%
batch = next(iter(train_iter))

# %%
t1 = (tf.cast(batch['t1'], tf.float32)-t1_mean)/t1_std
t2 = (batch['t2']-t2_mean)/t2_std
ad = batch['ad']
ad = tf.where(tf.math.is_nan(ad), tf.zeros_like(ad), ad)
ad = (ad-ad_mean)/ad_std
fa = batch['fa']
fa = tf.where(tf.math.is_nan(fa), tf.zeros_like(fa), fa)
fa = (fa-fa_mean)/fa_std
md = batch['md']
md = tf.where(tf.math.is_nan(md), tf.zeros_like(md), md)
md = (md-md_mean)/md_std
rd = batch['rd']
rd = tf.where(tf.math.is_nan(rd), tf.zeros_like(rd), rd)
rd = (rd-rd_mean)/rd_std
#subjectid = decoder(batch['subjectid'])
#y = get_labels(df, subjectid, list(cat_cols.keys())+num_cols)
#X = tf.concat([t1, t2, ad, fa, md, rd], axis=4)
X = tf.concat([t1, t2], axis=4)

# %%
tf.keras.backend.set_learning_phase(True)
model(X)['female']

# %%
tf.keras.backend.set_learning_phase(False)
model(X)['female']

# %%
mean_std = [x.name for x in model.non_trainable_variables if ('batch_norm') in x.name and ('mean' in x.name or 'variance' in x.name)]

# %%
model = Model(cat_cols, num_cols)

# %%
model.non_trainable_variables
